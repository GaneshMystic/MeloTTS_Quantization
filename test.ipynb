# %%
import requests

# %%
requests.get("https://api.github.com")
# Out:
# <Response [200]>

# %%
from requests.exceptions import HTTPError

URLS = ["https://api.github.com", "https://api.github.com/invalid"]

for url in URLS:
    try:
        response = requests.get(url)
        response.raise_for_status()
    except HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except Exception as err:
        print(f"Other error occurred: {err}")
    else:
        print("Success!")
# Out:
# Success!
# HTTP error occurred: 404 Client Error: Not Found for url: https://api.github.com/invalid

# %%
response.content
# Out:
# b'{"message":"Not Found","documentation_url":"https://docs.github.com/rest"}'

# %%
response.text
# Out:
# '{"message":"Not Found","documentation_url":"https://docs.github.com/rest"}'

# %%
response_dict = response.json()
response_dict["message"]
# Out:
# 'Not Found'

# %%
# Search GitHub's repositories for popular Python projects
response = requests.get(
    "https://api.github.com/search/repositories",
    params={"q": "language:python", "sort": "stars", "order": "desc"},
)

# Inspect some attributes of the first three repositories
json_response = response.json()
popular_repositories = json_response["items"]
for repo in popular_repositories[:3]:
    print(f"Name: {repo['name']}")
    print(f"Description: {repo['description']}")
    print(f"Stars: {repo['stargazers_count']}")
    print()
# Out:
# Name: public-apis
# Description: A collective list of free APIs
# Stars: 291439
#
# Name: system-design-primer
# Description: Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.
# Stars: 252745
#
# Name: awesome-python
# Description: An opinionated list of awesome Python frameworks, libraries, software and resources.
# Stars: 204260

# %%
response = requests.post("https://httpbin.org/post", data={"key": "value"})
response.content
# Out:
# b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key": "value"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "9", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-661eb24d-24782d5e299ebcba5fb8d1d0"\n  }, \n  "json": null, \n  "origin": "157.46.82.156", \n  "url": "https://httpbin.org/post"\n}\n'

# %% [markdown]
# #API Backend

# %%
from flask import Flask
app = Flask(__name__)
@app.route('/')
def hello_world():
    return 'Hello, World!'
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %%
from flask import Flask, render_template, send_file, Response


app = Flask(__name__)

@app.route('/')
def hello_world():
    return 'Hello, World!'




@app.route("/tts", methods=["POST"])
def testpost():
    return send_file("en-us.wav", mimetype="audio/wav")


if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
import requests
import json

url = "http://localhost:11434/api/generate"

payload = json.dumps({
  "model": "m-1",
  "prompt": "How are you?",
  "stream": False
})
headers = {
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

# %%
print(response.json()["response"])
# Out:
# As an AI focused on programming assistant's response, I focus primarily around providing assistance related to computer science topics such as coding problems or concepts in a particular language like Python for example.
# However, from your question about "meaning of life", which seems more philosophical rather than directly tied towards computing the subjective concept 'life', it is not within my area's expertise and knowledge base I can provide an answer to this problem either way - as long both parties involved are engaged in a meaningful discussion regarding meaning-based conversations.

# %%
import requests

model_response = "sample testing text"
tts_url = "http://127.0.0.1:5002/tts?text="+model_response+"&speed=1"

payload = {}
headers = {}

response = requests.request("GET", tts_url)

# %%
response.content
# Out:
# b'RIFF^\xf1\x02\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x01\x00D\xac\x00\x00\x88X\x01\x00\x02\x00\x10\x00data:
# ...
